# %%
import ast
import numpy as np
import pandas as pd

def convert(obj):
    l=[]
    for i in ast.literal_eval(obj) :
        # ast.literal_eval works like the eval that if we give a string which
        # is of form of a dictonary then it makes it a dictinory object
        l.append(i['name'])
    return l

def convert3(obj):
    l = []
    counter = 0
    for i in ast.literal_eval(obj) :
        if counter != 3 :
            l.append(i['name'])
            counter+=1
        else : 
            break
        return l

def fetchDirector(obj):
    l= []
    for i in ast.literal_eval(obj) :
        if i['job'].capitalize() == 'Director' :
            l.append(i['name'])
    return l

# %%
credits_df=pd.read_csv("dataset/credits.csv")
movies_df=pd.read_csv("dataset/movies.csv")

# %%
merged=movies_df.merge(credits_df,on="title")
merged.tail(2)
# Out:
#       budget                               genres  \
# 4806       0                                   []
# 4807       0  [{"id": 99, "name": "Documentary"}]
#
#                          homepage      id  \
# 4806  http://shanghaicalling.com/  126186
# 4807                          NaN   25975
#
#                                                keywords original_language  \
# 4806                                                 []                en
# 4807  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4807  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
# ...

# %%
merged["crew"][2]
# Out:
# '[{"credit_id": "54805967c3a36829b5002c41", "department": "Sound", "gender": 2, "id": 153, "job": "Original Music Composer", "name": "Thomas Newman"}, {"credit_id": "52fe4d22c3a368484e1d8d77", "department": "Directing", "gender": 2, "id": 39, "job": "Director", "name": "Sam Mendes"}, {"credit_id": "5677cd99925141691a005333", "department": "Art", "gender": 1, "id": 8384, "job": "Set Decoration", "name": "Anna Pinnock"}, {"credit_id": "52fe4d22c3a368484e1d8d8d", "department": "Writing", "gender": 2, "id": 932, "job": "Screenplay", "name": "John Logan"}, {"credit_id": "562fc9bb92514129fe0006b4", "department": "Writing", "gender": 2, "id": 932, "job": "Story", "name": "John Logan"}, {"credit_id": "5654d41c92514145c3000373", "department": "Art", "gender": 2, "id": 4248, "job": "Production Design", "name": "Dennis Gassner"}, {"credit_id": "52fe4d22c3a368484e1d8d71", "department": "Writing", "gender": 2, "id": 9856, "job": "Characters", "name": "Ian Fleming"}, {"credit_id": "54805989c3a3682
# ...

# %%
show_row = merged.iloc[2607]
show_row
# Out:
# budget                                                                  0
# genres                                  [{"id": 10751, "name": "Family"}]
# homepage                                                              NaN
# id                                                                  17644
# keywords                                                               []
# original_language                                                      en
# original_title                                   Barney's Great Adventure
# overview                Mom and dad dump son Cody, daughter Abby, her ...
# popularity                                                       0.722911
# production_companies    [{"name": "PolyGram Filmed Entertainment", "id...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   01-01-1998
# revenue                                                                 0
# ...

# %%
merged['genres'] = merged['genres'].apply(convert)
merged.tail(2)
# Out:
#       budget         genres                     homepage      id  \
# 4806       0             []  http://shanghaicalling.com/  126186
# 4807       0  [Documentary]                          NaN   25975
#
#                                                keywords original_language  \
# 4806                                                 []                en
# 4807  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4807  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#      runtime                          spoken_languages    status  \
# ...

# %%
merged['keywords'] = merged['keywords'].apply(convert)
merged.tail(2)
# Out:
#       budget         genres                     homepage      id  \
# 4806       0             []  http://shanghaicalling.com/  126186
# 4807       0  [Documentary]                          NaN   25975
#
#                                        keywords original_language  \
# 4806                                         []                en
# 4807  [obsession, camcorder, crush, dream girl]                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4807  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#      runtime                          spoken_languages    status  \
# ...

# %%
merged['cast'] = merged['cast'].apply(convert3)
merged.tail(2)
# Out:
#       budget         genres                     homepage      id  \
# 4806       0             []  http://shanghaicalling.com/  126186
# 4807       0  [Documentary]                          NaN   25975
#
#                                        keywords original_language  \
# 4806                                         []                en
# 4807  [obsession, camcorder, crush, dream girl]                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4807  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#      runtime                          spoken_languages    status  \
# ...

# %%
merged['crew'] = merged['crew'].apply(fetchDirector)
print(merged['crew'][1])
print(merged['crew'][4807])
# Out:
# ['Gore Verbinski']
# ['Brian Herzlinger', 'Jon Gunn', 'Brett Winn']

# %%
x = merged['overview'][0]
splited = x.split()
print(splited)
# Out:
# ['In', 'the', '22nd', 'century,', 'a', 'paraplegic', 'Marine', 'is', 'dispatched', 'to', 'the', 'moon', 'Pandora', 'on', 'a', 'unique', 'mission,', 'but', 'becomes', 'torn', 'between', 'following', 'orders', 'and', 'protecting', 'an', 'alien', 'civilization.']

# %%
merged['overview'] = merged['overview'].apply(lambda x: str(x).split())
merged.head(2)
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# 1  [Captain, Barbossa,, long, believed, to, be, d...  139.082615
#
# ...

# %%
merged.tail(2)
# Out:
#       budget         genres                     homepage      id  \
# 4806       0             []  http://shanghaicalling.com/  126186
# 4807       0  [Documentary]                          NaN   25975
#
#                                        keywords original_language  \
# 4806                                         []                en
# 4807  [obsession, camcorder, crush, dream girl]                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  [When, ambitious, New, York, attorney, Sam, is...
# 4807  My Date with Drew  [Ever, since, the, second, grade, when, he, fi...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#      runtime                          spoken_languages    status  \
# ...

# %%
merged['genres'] = merged['genres'].apply(lambda x : [i.replace(" ","") for i in x ])
merged['keywords'] = merged['keywords'].apply(lambda x: [s.replace(' ', '') for s in x])
merged.tail()
# Out:
#       budget                             genres  \
# 4803  220000          [Action, Crime, Thriller]
# 4804    9000                  [Comedy, Romance]
# 4805       0  [Comedy, Drama, Romance, TVMovie]
# 4806       0                                 []
# 4807       0                      [Documentary]
#
#                                                homepage      id  \
# 4803                                                NaN    9367
# 4804                                                NaN   72766
# 4805  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4806                        http://shanghaicalling.com/  126186
# 4807                                                NaN   25975
#
#                                                keywords original_language  \
# 4803  [unitedstates–mexicobarrier, legs, arms, paper...                es
# 4804                                                 []                en
# ...

# %%
merged.to_csv('merged_data.csv', index=False)

# %%
# # ERROR FINDER
# counter = 0
# try:
#     for x in merged['cast']:
#         counter += 1
#         updated_list = [i.replace(" ", "") for i in x]

# except Exception as e:
#     print("Error occurred at counter:", counter)
#     print("Error message:", str(e))

# %%
merged['cast'] = merged['cast'].apply(lambda x: [i.replace(" ", "") for i in x] if x != None else [])

# %%
show_row = merged.iloc[2607]
show_row
# Out:
# budget                                                                  0
# genres                                                           [Family]
# homepage                                                              NaN
# id                                                                  17644
# keywords                                                               []
# original_language                                                      en
# original_title                                   Barney's Great Adventure
# overview                [Mom, and, dad, dump, son, Cody,, daughter, Ab...
# popularity                                                       0.722911
# production_companies    [{"name": "PolyGram Filmed Entertainment", "id...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   01-01-1998
# revenue                                                                 0
# ...

# %%
merged['crew'] = merged['crew'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
merged.tail(2)
# Out:
#       budget         genres                     homepage      id  \
# 4806       0             []  http://shanghaicalling.com/  126186
# 4807       0  [Documentary]                          NaN   25975
#
#                                       keywords original_language  \
# 4806                                        []                en
# 4807  [obsession, camcorder, crush, dreamgirl]                en
#
#          original_title                                           overview  \
# 4806   Shanghai Calling  [When, ambitious, New, York, attorney, Sam, is...
# 4807  My Date with Drew  [Ever, since, the, second, grade, when, he, fi...
#
#       popularity                               production_companies  ...  \
# 4806    0.857008                                                 []  ...
# 4807    1.929883  [{"name": "rusty bear entertainment", "id": 87...  ...
#
#      runtime                          spoken_languages    status  \
# ...

# %%
show_row = merged.iloc[2662]
show_row
# Out:
# budget                                                       15000000
# genres                                                        [Drama]
# homepage                                                          NaN
# id                                                             370980
# keywords                                            [pope, biography]
# original_language                                                  it
# original_title             Chiamatemi Francesco - Il Papa della gente
# overview                                                        [nan]
# popularity                                                   0.738646
# production_companies           [{"name": "Taodue Film", "id": 45724}]
# production_countries          [{"iso_3166_1": "IT", "name": "Italy"}]
# release_date                                               03-12-2015
# revenue                                                             0
# ...

# %%
# NEED CORRECTION
# THERE IS NAN IN 2662 position in the dataframe see the above cell


merged['tags'] = merged['overview'] + merged['genres'] + merged['keywords'] + merged['cast'] + merged['crew']

# %%
merged.head(2)
# Out:
#       budget                                        genres  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]
# 1  300000000                  [Adventure, Fantasy, Action]
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  150.437577
# 1  [Captain, Barbossa,, long, believed, to, be, d...  139.082615
#
#                                 production_companies  ...  \
# ...

# %%
new_df = merged[['movie_id', 'title', 'tags']]
new_df.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...

# %%
print(new_df['tags'][0])
# Out:
# ['In', 'the', '22nd', 'century,', 'a', 'paraplegic', 'Marine', 'is', 'dispatched', 'to', 'the', 'moon', 'Pandora', 'on', 'a', 'unique', 'mission,', 'but', 'becomes', 'torn', 'between', 'following', 'orders', 'and', 'protecting', 'an', 'alien', 'civilization.', 'Action', 'Adventure', 'Fantasy', 'ScienceFiction', 'cultureclash', 'future', 'spacewar', 'spacecolony', 'society', 'spacetravel', 'futuristic', 'romance', 'space', 'alien', 'tribe', 'alienplanet', 'cgi', 'marine', 'soldier', 'battle', 'loveaffair', 'antiwar', 'powerrelations', 'mindandsoul', '3d', 'SamWorthington', 'JamesCameron']

# %%
counter = 0
try:
    for x in new_df['tags']:
        updated_list = " ".join(x)
        counter += 1

except Exception as e:
    print("Error occurred at counter:", counter)
    print("Error message:", str(e))

# %%
print(new_df['tags'][2662])
# Out:
# ['nan', 'Drama', 'pope', 'biography', 'RodrigodelaSerna', 'DanieleLuchetti']

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : " ".join(x))
# counter = 0
# for i in new_df['tags'] : 
#     counter +=1
#     if isinstance(i,list) :
#         f=10
#     else :
#         print(i)
#         print(type(i))
#         print(counter)
#         # print(i.index)

new_df
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_17172\2562464528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : " ".join(x))
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_17172\3679624391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : x.lower())

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4803      9367                               El Mariachi
# 4804     72766                                 Newlyweds
# 4805    231617                 Signed, Sealed, Delivered
# 4806    126186                          Shanghai Calling
# 4807     25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

def stem(text):
    stemmed = []
    for i in text.split():
        stemmed.append(ps.stem(i))
    return " ".join(stemmed)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
vectors = cv.fit_transform(new_df['tags']).toarray()

# converts each row of the column into an array of number of times each word is repeated
# Ex : text = [‘Hello my name is james, this is my python notebook’]
# This gives 
#  Hello    my   name    is   james   python     notebook
#    1       2     1      2     1       1          1
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_17172\3001756783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.0860309 , 0.08740748, ..., 0.04499213, 0.        ,
#        0.        ])

# %%
# JUST AN EXAMPLE
movie_list = sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])[1:6]

# here list of similarity[0] is enumerated and sorted according to the key at 1 position of  
# each elements that is the value itself as it moves to position 1 when enumerated

# %%
def recommend(movie):
    movieIndex = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movieIndex]
    movie_list = sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])[1:6]
